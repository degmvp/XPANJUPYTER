# %%
import pandas as pd

# %%
df  = pd.read_csv('all_data.csv')
dfc = pd.read_csv('compras.csv', sep=';')

# %%
df.head(3)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001
# 1             NaN                                NaN
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215

# %%
df.shape
# Out:
# (186850, 6)

# %%
print(df)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
display(df)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
varprod = df['Product']
display(varprod)
# Out:
# 0               USB-C Charging Cable
# 1                                NaN
# 2         Bose SoundSport Headphones
# 3                       Google Phone
# 4                   Wired Headphones
#                      ...
# 186845        AAA Batteries (4-pack)
# 186846                        iPhone
# 186847                        iPhone
# 186848        34in Ultrawide Monitor
# 186849          USB-C Charging Cable
# Name: Product, Length: 186850, dtype: object

# %%
varprod1 = df[['Product','Order ID']]
varprod1
# Out:
#                            Product Order ID
# 0             USB-C Charging Cable   176558
# 1                              NaN      NaN
# 2       Bose SoundSport Headphones   176559
# 3                     Google Phone   176560
# 4                 Wired Headphones   176560
# ...                            ...      ...
# 186845      AAA Batteries (4-pack)   259353
# 186846                      iPhone   259354
# 186847                      iPhone   259355
# 186848      34in Ultrawide Monitor   259356
# 186849        USB-C Charging Cable   259357
#
# [186850 rows x 2 columns]

# %%
df.loc[1:5]
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
display(df.loc[df['Product'] == 'Google Phone'])
# Out:
#        Order ID       Product Quantity Ordered Price Each      Order Date  \
# 3        176560  Google Phone                1        600  04/12/19 14:38
# 11       176567  Google Phone                1        600  04/18/19 17:18
# 18       176574  Google Phone                1        600  04/03/19 19:42
# 33       176586  Google Phone                1        600  04/10/19 17:00
# 37       176590  Google Phone                1        600  04/11/19 11:46
# ...         ...           ...              ...        ...             ...
# 186639   259159  Google Phone                1        600  09/09/19 13:40
# 186713   259231  Google Phone                1        600  09/04/19 23:19
# 186741   259258  Google Phone                1        600  09/09/19 19:16
# 186753   259270  Google Phone                1        600  09/06/19 15:27
# 186841   259350  Google Phone                1        600  09/30/19 13:49
#
#                               Purchase Address
# ...

# %%
display(df.loc[df['Product'] == 'Google Phone', ['Order ID', 'Product']])
# Out:
#        Order ID       Product
# 3        176560  Google Phone
# 11       176567  Google Phone
# 18       176574  Google Phone
# 33       176586  Google Phone
# 37       176590  Google Phone
# ...         ...           ...
# 186639   259159  Google Phone
# 186713   259231  Google Phone
# 186741   259258  Google Phone
# 186753   259270  Google Phone
# 186841   259350  Google Phone
#
# [5525 rows x 2 columns]

# %%
df.loc[37, 'Purchase Address']
# Out:
# '873 6th St, New York City, NY 10001'

# %%
df = df.drop('Value', axis=1)

# %%
df = df.drop('imposto', axis=1)
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df['Value'] = df['Quantity Ordered']

# %%
df.loc[:, "imposto"] = 0

# %%
df1 = pd.read_csv('Dec_2019.csv')

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
df = df.append(df1)
display(df)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15072\1353099835.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1)
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# ...

# %%
#deletar linhas e colunas vazias
#df = df.dropna(how='all', axis=1)

#deletar linhas que possuem pelo menos 1 valor NaN
df = df.dropna()

#preencher valores vazios com a media da coluna
#df['Value'] = df['Value'].fillna(df['Value'].mean())

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# 5       176561            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1      14.95
# 25113   319667       AA Batteries (4-pack)                2       3.84
# 25114   319668             Vareebadd Phone                1        400
# 25115   319669            Wired Headphones                1      11.99
# 25116   319670  Bose SoundSport Headphones                1      99.99
#
#            Order Date                        Purchase Address
# ...

# %%
df_count = df['Order ID'].value_counts()
display(df_count)
# Out:
# Order ID    451
# 296353       12
# 312462       12
# 312407       12
# 295681       12
#            ...
# 225655        1
# 225656        1
# 225657        1
# 225658        1
# 259357        1
# Name: Order ID, Length: 178438, dtype: int64

# %%
dfc
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...

# %%
print(dfc)
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade  ValorUnitário  ValorFinal
# 0              Óleo Motor - Linha A           5         259.00     1295.00
# 1           Kit Embreagem - Linha A           1         380.00      380.00
# ...

# %%
dfc.shape
# Out:
# (4543, 7)

# %%
dfc.index
# Out:
# RangeIndex(start=0, stop=4543, step=1)

# %%
dfc.columns
# Out:
# Index(['CódigoCompra', 'Data', 'Fornecedor', 'Produto', 'Quantidade',
#        'ValorUnitário', 'ValorFinal'],
#       dtype='object')
