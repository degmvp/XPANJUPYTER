# %%
import matplotlib.pyplot as plt

# %%
from  matplotlib import pyplot as plt

# %%
X = [1, 4, 2, 6]
Y = ['Eduardo', 'Lucas', 'Regis', 'Degmar']

# %%
X.append(5)
Y.append('Alex')

# %%
plt.pie(X, labels=Y)
plt.show()
